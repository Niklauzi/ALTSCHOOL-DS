# %% [markdown]
# ## Assumptions for Starting Introduction to ML

# %%
# You must have some Python Programming Experience 
# You must be familiar with Pandas, Numpy, Matplotlib, Seaborn & Tableau 
# Understanding a few concepts in Statistics is critical

# %% [markdown]
# ### What is ML
#
# A computer program is said to learn from experience E with respect to some task
# T and some performance measure P, if its performance on T, as measured by P,
# improves with experience E.
# —Tom Mitchell, 1997

# %%
# One of the classic ML application is the Spam Detector

# %% [markdown]
# ### Why ML

# %%
# import display
from IPython import display

# %%
# Why ML
display.Image("traditional_approach.png")

# %%
# This was not sustainable 👆🏽

# %%
# ML Approach
display.Image("ml_approach.png")

# %%
# We take historical data/examples/instances/features

# %%
# Spam Detection
display.Image("classification.png")

# %% [markdown]
# A computer program is said to learn from experience E (Training Data) for some task
# T (flag spam from new emails) and some performance measure P (ratio of correctly classified email). If its performance on T, as measured by P,
# improves with experience E. —Tom Mitchell, 1997

# %%
# ML system adapts to change 
display.Image("adapting_change.png")

# %% [markdown]
# ### ML Road Map

# %%
# What is ML?
# What problems it tries to solve - repetitive activities 
# ML Categories 
# Steps in Typical ML Projects
# Performance measures 
# Handling, Cleaning & Preparing Data 
# Selection and engineering features 
# Selection of Models - Assumptions 
# Challenges of ML: Bad data, Bad Model
# Common Learning Algorithms

# %% [markdown]
# ### How ML helps Humans

# %%
# Reveals Unsuspected Relationships in Data
# Helps us discover trends and patterns hidden from us

# %%
display.Image("ml_helps_humans.png")

# %% [markdown]
# ### Types of ML Systems

# %%
# Supervised and Unsupervised 
# Learning systems - Learn on the fly or learn in batches 
# Pattern detections - Instance-based or Model-based

# %% [markdown]
# ### Supervised Learning
#
# Labeled Training sets

# %%
display.Image("classification.png")
# Spam filter - Supervised learning task
# Predicts classes (spam or ham), Male/Female, Yes/No

# %%
# Spervised - Learning to predict values 
# Regression task 
display.Image("regression.png")

# %%
# Target(Regression) or Labels(Classification)
# Features

# %% [markdown]
# ### Unsupervised Learning

# %%
# Clustering 
# Anomaly detection 
# Novelty Detection

# %%
display.Image("clustering .png")

# %%
# Batch vs Online learning
# Instance based vs Model Based Learning

# %% [markdown]
# ### Model Based Learning & a Typical ML Workflow

# %%
# Generalise from a set of examples
# We prep this examples to model the real life assumptions

# %%
display.Image("model_based_ml.png")

# %% [markdown]
# ### Main Challenges of ML

# %%
# Insufficient Quantity of Training Data
# Nonrepresentative Training Data
# Poor Quality Data - full of errors, missing values, outliers - Noise/Signal
# Irrelevant features - garbage in, garbage out
# Overfitting of Training Data
# Underfitting your data

# %% [markdown]
# ### Small ML Workflow

# %%
# Frame of the problem - Predict a Country’s life Satisfaction 
# Judge life Satisfaction Using GDP Per Capita

# %%
# import the pandas package
import pandas as pd

# %%
# This is our data
full_country_stats = pd.read_csv("lifesat_full.csv")
full_country_stats.shape
# Out:
# (36, 3)

# %%
full_country_stats.head() # This our full data
# Out:
#         Country  GDP per capita (USD)  Life satisfaction
# 0  South Africa          11466.189672                4.7
# 1      Colombia          13441.492952                6.3
# 2        Brazil          14063.982505                6.4
# 3        Mexico          17887.750736                6.5
# 4         Chile          23324.524751                6.5

# %%
# make the country column the index
full_country_stats.index = full_country_stats['Country']

# %%
full_country_stats.head()
# Out:
#                    Country  GDP per capita (USD)  Life satisfaction
# Country
# South Africa  South Africa          11466.189672                4.7
# Colombia          Colombia          13441.492952                6.3
# Brazil              Brazil          14063.982505                6.4
# Mexico              Mexico          17887.750736                6.5
# Chile                Chile          23324.524751                6.5

# %%
# del the Country column
del full_country_stats['Country']

# %%
min_gdp = 23_500
max_gdp = 62_500

# %%
# Limited data
country_stats = full_country_stats[(full_country_stats["GDP per capita (USD)"] >= min_gdp) & 
(full_country_stats["GDP per capita (USD)"] <= max_gdp)]

# %%
country_stats.head()
# Out:
#          GDP per capita (USD)  Life satisfaction
# Country
# Russia           26456.387938                5.8
# Greece           27287.083401                5.4
# Turkey           28384.987785                5.5
# Latvia           29932.493910                5.9
# Hungary          31007.768407                5.6

# %%
# import our packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
# visualize our data
country_stats.plot(kind='scatter', grid=True, x= "GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4,9])
plt.show()

# %%
# Let's visualize with context
country_stats.plot(kind='scatter', figsize=(5, 3), grid=True,
                   x='GDP per capita (USD)', y='Life satisfaction')

min_life_sat = 4
max_life_sat = 9

position_text = {
    "Turkey": (29_500, 4.2),
    "Hungary": (28_000, 6.9),
    "France": (40_000, 5),
    "New Zealand": (28_000, 8.2),
    "Australia": (50_000, 5.5),
    "United States": (59_000, 5.3),
    "Denmark": (46_000, 8.5)
}

for country, pos_text in position_text.items():
    pos_data_x = country_stats['GDP per capita (USD)'].loc[country]
    pos_data_y = country_stats['Life satisfaction'].loc[country]
    country = "U.S." if country == "United States" else country
    plt.annotate(country, xy=(pos_data_x, pos_data_y),
                 xytext=pos_text, fontsize=12,
                 arrowprops=dict(facecolor='black', width=0.5,
                                 shrink=0.08, headwidth=5))
    plt.plot(pos_data_x, pos_data_y, "ro")

plt.axis([min_gdp, max_gdp, min_life_sat, max_life_sat])

#save_fig('money_happy_scatterplot')
plt.show()

# %%
# Select a linear model
model = LinearRegression()

X = country_stats[["GDP per capita (USD)"]].values
y =country_stats[["Life satisfaction"]].values

# Select a linear model
model = LinearRegression()

# %%
# Train the model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Predict Cyprus
# As of 2020, the GDP Per Capita 
X_new = [[37_655.2]]
print(model.predict(X_new))
# Out:
# [[6.30165767]]

# %%
# Full dataset
full_country_stats.shape
# Out:
# (36, 2)

# %%
missing_data = full_country_stats[(full_country_stats["GDP per capita (USD)"] < min_gdp) | 
(full_country_stats["Life satisfaction"] > max_gdp)]

# %%
missing_data
# Out:
#               GDP per capita (USD)  Life satisfaction
# Country
# South Africa          11466.189672                4.7
# Colombia              13441.492952                6.3
# Brazil                14063.982505                6.4
# Mexico                17887.750736                6.5
# Chile                 23324.524751                6.5

# %%
# visualize our data
full_country_stats.plot(kind='scatter', grid=True, x= "GDP per capita (USD)", y="Life satisfaction")
plt.axis([10_500, 120_000, 4,9])
plt.show()

# %%
from sklearn import linear_model

X_sample = country_stats[["GDP per capita (USD)"]].values
y_sample = country_stats[["Life satisfaction"]].values

lin1 = linear_model.LinearRegression()
lin1.fit(X_sample, y_sample)

t0, t1 = lin1.intercept_[0], lin1.coef_[0][0]
print(f"θ0={t0:.2f}, θ1={t1:.2e}")
# Out:
# θ0=3.75, θ1=6.78e-05

# %%
position_text_missing_countries = {
    "South Africa": (20_000, 4.2),
    "Colombia": (6_000, 8.2),
    "Brazil": (18_000, 7.8),
    "Mexico": (24_000, 7.4),
    "Chile": (30_000, 7.0),
}

# %%
# Visualise the full data
full_country_stats.plot(kind='scatter', figsize=(8, 3),
                        x="GDP per capita (USD)", y="Life satisfaction", grid=True)

for country, pos_text in position_text_missing_countries.items():
    pos_data_x, pos_data_y = missing_data.loc[country]
    plt.annotate(country, xy=(pos_data_x, pos_data_y),
                 xytext=pos_text, fontsize=12,
                 arrowprops=dict(facecolor='black', width=0.5,
                                 shrink=0.08, headwidth=5))
    plt.plot(pos_data_x, pos_data_y, "rs")

X = np.linspace(0, 115_000, 1000)
plt.plot(X, t0 + t1 * X, "b:")

lin_reg_full = linear_model.LinearRegression()
Xfull = np.c_[full_country_stats["GDP per capita (USD)"]]
yfull = np.c_[full_country_stats["Life satisfaction"]]
lin_reg_full.fit(Xfull, yfull)

t0full, t1full = lin_reg_full.intercept_[0], lin_reg_full.coef_[0][0]
X = np.linspace(0, 115_000, 1000)
plt.plot(X, t0full + t1full * X, "k")

plt.axis([0, 115_000, min_life_sat, max_life_sat])

#save_fig('representative_training_data_scatterplot')
plt.show()

# %% [markdown]
# ### End-to-End ML Project
#
# 1. Look at the big picture
#  * Frame the problem
#  * Select a performance measure
#  * Check the assumption
#
# 2. Get the data
#    * Download the data
#    * Take a quick look at the data structure
#    * Create a test set
#    * Explore and visualize the data to gain insight
#    * Look for correlations
#    * Experiment with attribute combinations
#
# 3. Prepare the data for machine learning algorithms
#    * Clean the data
#    * Handling text and categorical attributes
#    * Feature scaling and transformation
#    * Custom transformers
#    * Transformation pipelines
#
# 4. Select a model and train a model
#    * Train and evaluate the training set
#    * Better evaluation using cross-validation
#
# 5. Fine-tune your model
#    * Grid search
#    * Randomized search
#    * Ensemble methods
#    * Analysing the best models and their errors
#    * Evaluate your system on the test set
#
#
# 6. Launch, monitor, and maintain your system

# %% [markdown]
# ### Hypothetically - Real Estate Business

# %%
# The Big Picture - Build a Model for housing price 
# Predict the Median Housing Price
# Problem - The current situation is costly and time consuming, the estimates are not great
# Whenever estimates are made, they fall short - 30%

# %% [markdown]
# ### Select a Performance Measure

# %%
# Example of a performance measures 
display.Image("RMSE.png")

# %% [markdown]
# ### Our Imported Packages

# %%
# import packages
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
from pathlib import Path

# %%
IMAGES_PATH = Path() / "images" / "end_to_end_project"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# # Our Data
# housing_data = pd.read_csv("housing.csv")
# housing_data.head()

# %%
# The number of rows and columns
housing_data.shape
# Out:
# (20640, 10)

# %% [markdown]
# ### Check the assumptions

# %%
# How will your predictions be used 
# Who will use your prediction 
# Is there a downstream system?

# %% [markdown]
# ### Get the Data

# %%
# Checking our the structure of the data
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# Quick description 
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# check out the object datatype 
housing_data['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
# Mean, median, std, 
# Descriptive Statistics

# %%
# Get a feel of your data 
# By visualizing
housing_data.hist(bins=50, figsize=(12,8))
plt.show()

# %% [markdown]
# ### Create a test

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing_data, test_size=0.2, random_state=42)

# %%
train_set.shape
# Out:
# (16512, 10)

# %%
# Random sampling method - If your data is large - introduce sampling bias 
# Stratified Sampling method - Ratio of the features in your sample

# %%
# When creating a test set, let it reflect the whole dataset

# %%
# Reflecting the categories in the main dataset
housing_data['median_income'].head()
# Out:
# 0    8.3252
# 1    8.3014
# 2    7.2574
# 3    5.6431
# 4    3.8462
# Name: median_income, dtype: float64

# %%
housing_data['income_cat'] = pd.cut(housing_data['median_income'], bins=[0.,1.5,3.0, 4.5, 6., np.inf],
                                    labels=[1,2,3,4,5])

# %%
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   income_cat
# 0          5
# 1          5
# 2          5
# ...

# %%
housing_data["income_cat"].value_counts().sort_index().plot.bar(rot=0, grid=True)
plt.xlabel("Income category")
plt.ylabel("Number of districts")
save_fig("housing_income_cat_bar_plot")  # extra code
plt.show()

# %%
# a single split using the train_test_split() function with the stratify argument
strat_train_set, strat_test_set = train_test_split(
    housing_data, test_size=0.2, stratify=housing_data["income_cat"], random_state=42)

# %%
strat_train_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13096    -122.42     37.80                52.0       3321.0          1115.0
# 14973    -118.38     34.14                40.0       1965.0           354.0
# 3785     -121.98     38.36                33.0       1083.0           217.0
# 14689    -117.11     33.75                17.0       4174.0           851.0
# 20507    -118.15     33.77                36.0       4366.0          1211.0
#
#        population  households  median_income  median_house_value  \
# 13096      1576.0      1034.0         2.0987            458300.0
# 14973       666.0       357.0         6.0876            483800.0
# 3785        562.0       203.0         2.4330            101700.0
# 14689      1845.0       780.0         2.2618             96100.0
# 20507      1912.0      1172.0         3.5292            361800.0
#
#       ocean_proximity income_cat
# 13096        NEAR BAY          2
# 14973       <1H OCEAN          5
# ...

# %%
# Drop the income_cat column
for set_ in (strat_train_set, strat_test_set):
    set_.drop("income_cat", axis=1, inplace=True)

# %% [markdown]
# ### Explore and Visualize the Data to gain Insights

# %%
# Let me make a copy
housing_data = strat_train_set.copy()

# %%
# Bad Viz 
housing_data.plot(kind="scatter", x="longitude", y="latitude", grid=True)
save_fig("bad_visualization_plot")  # extra code
plt.show()

# %%
# Better Viz
housing_data.plot(kind="scatter", x="longitude", y="latitude", grid=True, alpha=0.2)
save_fig("better_visualization_plot")  # extra code
plt.show()

# %%
# Visualising housing price
housing_data.plot(kind="scatter", x="longitude", y="latitude", grid=True,
             s=housing_data["population"] / 100, label="population",
             c="median_house_value", cmap="jet", colorbar=True,
             legend=True, sharex=False, figsize=(10, 7))
save_fig("housing_prices_scatterplot")  # extra code
plt.show()

# %%
### Correlations
corr_matrix = housing_data.corr(numeric_only=True)

# %%
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688380
# total_rooms           0.137455
# housing_median_age    0.102175
# households            0.071426
# total_bedrooms        0.054635
# population           -0.020153
# longitude            -0.050859
# latitude             -0.139584
# Name: median_house_value, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes = ["median_house_value", "median_income", "total_rooms",
              "housing_median_age"]
scatter_matrix(housing_data[attributes], figsize=(12, 8))
save_fig("scatter_matrix_plot")  # extra code
plt.show()
