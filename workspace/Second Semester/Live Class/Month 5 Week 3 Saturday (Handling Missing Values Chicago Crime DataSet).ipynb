# %%
import pandas as pd

# %%
df = pd.read_csv('chicago1.csv')

# %%
df.head(50)
# Out:
#     Unnamed: 0        ID Case Number                    Date  \
# 0            0   6407111    HP485721  07/26/2008 02:30:00 PM
# 1            1  11398199    JB372830  07/31/2018 10:57:00 AM
# 2            2   5488785    HN308568  04/27/2007 10:30:00 AM
# 3            3  11389116    JB361368  07/23/2018 08:55:00 AM
# 4            4  12420431    JE297624  07/11/2021 06:40:00 AM
# 5            5   1699235     G498287  08/21/2001 12:00:00 AM
# 6            6   5061155    HM660983  10/14/2006 10:00:00 PM
# 7            7   9876456    HX527438  12/02/2014 11:48:00 AM
# 8            8   7582927    HS386492  06/30/2010 01:00:00 AM
# 9            9  10566046    HZ313634  06/18/2016 11:15:00 PM
# 10          10   9466303    HX118914  01/18/2014 09:00:00 AM
# 11          11   6577203    HP649357  10/26/2008 05:00:00 PM
# 12          12   8373423    HT607627  11/19/2011 09:00:00 AM
# 13          13   3298634    HK328238  04/25/2004 04:00:00 PM
# ...

# %%
df.head(30)
# Out:
#     Unnamed: 0        ID Case Number                    Date  \
# 0            0   6407111    HP485721  07/26/2008 02:30:00 PM
# 1            1  11398199    JB372830  07/31/2018 10:57:00 AM
# 2            2   5488785    HN308568  04/27/2007 10:30:00 AM
# 3            3  11389116    JB361368  07/23/2018 08:55:00 AM
# 4            4  12420431    JE297624  07/11/2021 06:40:00 AM
# 5            5   1699235     G498287  08/21/2001 12:00:00 AM
# 6            6   5061155    HM660983  10/14/2006 10:00:00 PM
# 7            7   9876456    HX527438  12/02/2014 11:48:00 AM
# 8            8   7582927    HS386492  06/30/2010 01:00:00 AM
# 9            9  10566046    HZ313634  06/18/2016 11:15:00 PM
# 10          10   9466303    HX118914  01/18/2014 09:00:00 AM
# 11          11   6577203    HP649357  10/26/2008 05:00:00 PM
# 12          12   8373423    HT607627  11/19/2011 09:00:00 AM
# 13          13   3298634    HK328238  04/25/2004 04:00:00 PM
# ...

# %%
df.index += 1

# %%
df.shape
# Out:
# (1000, 23)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Case Number', 'Date', 'Block', 'IUCR',
#        'Primary Type', 'Description', 'Location Description', 'Arrest',
#        'Domestic', 'Beat', 'District', 'Ward', 'Community Area', 'FBI Code',
#        'X Coordinate', 'Y Coordinate', 'Year', 'Updated On', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# Case Number              0
# Date                     0
# Block                    0
# IUCR                     0
# Primary Type             0
# Description              0
# Location Description     1
# Arrest                   0
# Domestic                 0
# Beat                     0
# District                 0
# Ward                     0
# Community Area          81
# FBI Code                 0
# X Coordinate             8
# Y Coordinate             8
# Year                     0
# Updated On               0
# Latitude                 8
# Longitude                8
# Location                 8
# dtype: int64

# %%
def missing_percentage(data):
    row, column = data.shape
    return data.isna().sum()/row * 100

# %%
missing_percentage(df)
# Out:
# Unnamed: 0              0.0
# ID                      0.0
# Case Number             0.0
# Date                    0.0
# Block                   0.0
# IUCR                    0.0
# Primary Type            0.0
# Description             0.0
# Location Description    0.1
# Arrest                  0.0
# Domestic                0.0
# Beat                    0.0
# District                0.0
# Ward                    0.0
# Community Area          8.1
# FBI Code                0.0
# X Coordinate            0.8
# Y Coordinate            0.8
# Year                    0.0
# Updated On              0.0
# Latitude                0.8
# Longitude               0.8
# Location                0.8
# dtype: float64

# %%
df
# Out:
#       Unnamed: 0        ID Case Number                    Date  \
# 1              0   6407111    HP485721  07/26/2008 02:30:00 PM
# 2              1  11398199    JB372830  07/31/2018 10:57:00 AM
# 3              2   5488785    HN308568  04/27/2007 10:30:00 AM
# 4              3  11389116    JB361368  07/23/2018 08:55:00 AM
# 5              4  12420431    JE297624  07/11/2021 06:40:00 AM
# ...          ...       ...         ...                     ...
# 996          995   5506743    HN325328  05/06/2007 02:08:51 AM
# 997          996   7959348    HT181792  02/27/2011 06:00:00 PM
# 998          997   3894749    HL263341  03/29/2005 05:30:00 PM
# 999          998   7000084    HR401314  06/29/2009 11:00:00 PM
# 1000         999   5155720    HM578375  09/02/2006 10:26:29 PM
#
#                        Block  IUCR       Primary Type  \
# 1       085XX S MUSKEGON AVE  1320    CRIMINAL DAMAGE
# 2          092XX S ELLIS AVE  143C  WEAPONS VIOLATION
# ...

# %%
df.Ward = df.Ward.interpolate(method='linear')

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# Case Number              0
# Date                     0
# Block                    0
# IUCR                     0
# Primary Type             0
# Description              0
# Location Description     1
# Arrest                   0
# Domestic                 0
# Beat                     0
# District                 0
# Ward                     0
# Community Area          81
# FBI Code                 0
# X Coordinate             8
# Y Coordinate             8
# Year                     0
# Updated On               0
# Latitude                 8
# Longitude                8
# Location                 8
# dtype: int64

# %%
df
# Out:
#       Unnamed: 0        ID Case Number                    Date  \
# 1              0   6407111    HP485721  07/26/2008 02:30:00 PM
# 2              1  11398199    JB372830  07/31/2018 10:57:00 AM
# 3              2   5488785    HN308568  04/27/2007 10:30:00 AM
# 4              3  11389116    JB361368  07/23/2018 08:55:00 AM
# 5              4  12420431    JE297624  07/11/2021 06:40:00 AM
# ...          ...       ...         ...                     ...
# 996          995   5506743    HN325328  05/06/2007 02:08:51 AM
# 997          996   7959348    HT181792  02/27/2011 06:00:00 PM
# 998          997   3894749    HL263341  03/29/2005 05:30:00 PM
# 999          998   7000084    HR401314  06/29/2009 11:00:00 PM
# 1000         999   5155720    HM578375  09/02/2006 10:26:29 PM
#
#                        Block  IUCR       Primary Type  \
# 1       085XX S MUSKEGON AVE  1320    CRIMINAL DAMAGE
# 2          092XX S ELLIS AVE  143C  WEAPONS VIOLATION
# ...

# %%
df.Ward.isna().sum()
# Out:
# 0

# %%
df
# Out:
#       Unnamed: 0        ID Case Number                    Date  \
# 1              0   6407111    HP485721  07/26/2008 02:30:00 PM
# 2              1  11398199    JB372830  07/31/2018 10:57:00 AM
# 3              2   5488785    HN308568  04/27/2007 10:30:00 AM
# 4              3  11389116    JB361368  07/23/2018 08:55:00 AM
# 5              4  12420431    JE297624  07/11/2021 06:40:00 AM
# ...          ...       ...         ...                     ...
# 996          995   5506743    HN325328  05/06/2007 02:08:51 AM
# 997          996   7959348    HT181792  02/27/2011 06:00:00 PM
# 998          997   3894749    HL263341  03/29/2005 05:30:00 PM
# 999          998   7000084    HR401314  06/29/2009 11:00:00 PM
# 1000         999   5155720    HM578375  09/02/2006 10:26:29 PM
#
#                        Block  IUCR       Primary Type  \
# 1       085XX S MUSKEGON AVE  1320    CRIMINAL DAMAGE
# 2          092XX S ELLIS AVE  143C  WEAPONS VIOLATION
# ...

# %%
df[df.Ward.isna()].head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.Ward.head()
# Out:
# 1    10.0
# 2     8.0
# 3    39.0
# 4    28.0
# 5    27.0
# Name: Ward, dtype: float64

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# Case Number              0
# Date                     0
# Block                    0
# IUCR                     0
# Primary Type             0
# Description              0
# Location Description     1
# Arrest                   0
# Domestic                 0
# Beat                     0
# District                 0
# Ward                     0
# Community Area          81
# FBI Code                 0
# X Coordinate             8
# Y Coordinate             8
# Year                     0
# Updated On               0
# Latitude                 8
# Longitude                8
# Location                 8
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 1 to 1000
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            1000 non-null   int64
#  1   ID                    1000 non-null   int64
#  2   Case Number           1000 non-null   object
#  3   Date                  1000 non-null   object
#  4   Block                 1000 non-null   object
#  5   IUCR                  1000 non-null   object
#  6   Primary Type          1000 non-null   object
#  7   Description           1000 non-null   object
#  8   Location Description  999 non-null    object
#  9   Arrest                1000 non-null   bool
#  10  Domestic              1000 non-null   bool
#  11  Beat                  1000 non-null   int64
#  12  District              1000 non-null   float64
#  13  Ward                  1000 non-null   float64
#  14  Community Area        919 non-null    float64
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0        ID Case Number                    Date  \
# 1           0   6407111    HP485721  07/26/2008 02:30:00 PM
# 2           1  11398199    JB372830  07/31/2018 10:57:00 AM
# 3           2   5488785    HN308568  04/27/2007 10:30:00 AM
#
#                   Block  IUCR       Primary Type               Description  \
# 1  085XX S MUSKEGON AVE  1320    CRIMINAL DAMAGE                TO VEHICLE
# 2     092XX S ELLIS AVE  143C  WEAPONS VIOLATION  UNLAWFUL POSS AMMUNITION
# 3     062XX N TRIPP AVE  0610           BURGLARY            FORCIBLE ENTRY
#
#   Location Description  Arrest  ...  Ward  Community Area  FBI Code  \
# 1               STREET   False  ...  10.0            46.0        14
# 2            POOL ROOM    True  ...   8.0            47.0        15
# 3            RESIDENCE    True  ...  39.0            12.0        05
#
#    X Coordinate  Y Coordinate  Year              Updated On   Latitude  \
# 1     1196638.0     1848800.0  2008  02/28/2018 03:56:25 PM  41.739980
# ...

# %%
df.Ward.unique()
# Out:
# array([10.        ,  8.        , 39.        , 28.        , 27.        ,
#        29.        , 37.        , 26.        , 35.        , 14.        ,
#         1.        , 17.        ,  3.        , 44.        , 32.        ,
#        36.        ,  4.        ,  2.        ,  6.        ,  7.        ,
#        40.        , 42.        , 31.        , 20.        , 13.        ,
#        11.        , 34.        , 47.        , 33.        ,  9.        ,
#        21.        , 45.        , 33.5       , 25.        , 24.        ,
#        15.        , 19.33333333, 23.66666667, 16.        , 19.        ,
#        43.        , 30.        , 23.        , 22.        ,  9.66666667,
#         9.33333333, 50.        , 25.5       , 49.        ,  5.        ,
#        12.5       , 46.        , 37.5       , 15.5       , 35.33333333,
#        35.66666667, 12.        , 10.5       , 16.5       , 41.        ,
#        38.        , 17.5       , 18.5       , 20.5       , 18.        ,
# ...

# %%
df.groupby('District').get_group(10)['Longitude']
# Out:
# 84    -87.723580
# 102   -87.716246
# 118   -87.729240
# 126   -87.711222
# 149   -87.712421
# 166   -87.717058
# 181   -87.715195
# 218   -87.734588
# 241   -87.704006
# 246   -87.704187
# 247   -87.673275
# 285   -87.705339
# 298   -87.701290
# 301   -87.733203
# 318   -87.692917
# 325   -87.720926
# 385   -87.695745
# 387   -87.685474
# 401   -87.702173
# 427   -87.702724
# 438   -87.696392
# 494   -87.717209
# 517   -87.705072
# 537   -87.724755
# 538   -87.729817
# 544   -87.694626
# 559   -87.705344
# 602   -87.718968
# 691   -87.724889
# 696   -87.693532
# 719   -87.706254
# 740   -87.716567
# 743   -87.709737
# 751   -87.714264
# 790   -87.709027
# 835   -87.686834
# 885   -87.731358
# 905   -87.724055
# 906   -87.706861
# 918   -87.705603
# 927   -87.725591
# 946   -87.736560
# 956   -87.722685
# 988   -87.699614
# 994   -87.719845
# Name: Longitude, dtype: float64
