# %% [markdown]
# - Subseting and Sorting Data
# - Grouping Data
# - Data Types
# - Handling Missing Data
# - Duplicates
# - Outliers

# %%
# loading the package
import pandas as pd

# %%
file = r'C:\Users\KLAUS\Desktop\JUPYTER\ALTSCHOOL-DS\workspace\Downloaded files\datasets\afcon-2023-final-squads-list.csv'

# %%
# load the data
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    shirt_no.                            name jersey_name position   birthdate  \
# 0          1  Signori Dominique Nymi António   Dominique       GK  25.07.1994
# 1          2   Nurio Domingos Matias Fortuna       Nurio       DF  24.03.1995
# 2          3          Buatu Mananga Jonathan       Buatu       DF  27.09.1993
# 3          4                  Keliano Manuel     Keliano       MF  16.01.2003
# 4          5    Joaquim Marcos Cunga Balanga      Kinito       DF  13.03.1998
#
#      team                            club club_country
# 0  Angola                  Etoile Carouge       Angola
# 1  Angola                         Gent KK       Angola
# 2  Angola                     Valencinnes       Angola
# 3  Angola              Estrela da Amadora       Angola
# 4  Angola  Atletico Petroleos de Luanda\n       Angola

# %% [markdown]
# - Subseting and Sorting Data

# %%
df[df['team'] == 'Angola']
# Out:
#     shirt_no.                                   name  jersey_name position  \
# 0           1         Signori Dominique Nymi António    Dominique       GK
# 1           2          Nurio Domingos Matias Fortuna        Nurio       DF
# 2           3                 Buatu Mananga Jonathan        Buatu       DF
# 3           4                         Keliano Manuel      Keliano       MF
# 4           5           Joaquim Marcos Cunga Balanga       Kinito       DF
# 5           6                        Kialonda Gaspar       Gaspar       DF
# 6           7                    Deivi Miguel Vieira     Gilberto       FW
# 7           8              Benedito Mambuene Mukendi         Beni       MF
# 8           9     Ambrósini António Cabaça\nSalvador         Zini       FW
# 9          10                    Jacinto Muondo Dala       Gelson       FW
# 10         11                    Felicio Mendes Joao       Milson       FW
# 11         12           Aldo Geraldo Manuel Monteiro         Kadu       GK
# 12         13  Corte Real Carneiro Augusto\nDe Jesus  To Carneiro       DF
# 13         14                  Loide Antonio Augusto        Loide       DF
# 14         15           Zito André Sebastiao Luvumbo      Luvumbo       FW
# 15         16                Alfredo Kulembe Ribeiro        Fredy       MF
# 16         17          Bruno L. Pinto De Almeida Paz    Bruno Paz       MF
# 17         18                           Jérémie Bela         Bela       FW
# 18         19                    Cristovao Paciencia     Mabululu       FW
# 19         20       Valdmiro Tualungo Paulo\nLameira      Estrela       MF
# 20         21               Eddie Marcos Melo Afonso        Eddie       DF
# 21         22               Adilson Da Cruz Cipriano        Neblu       GK
# 22         23          Manuel Luis Da Silva Cafumana         Show       MF
# 23         24                Francisco Pedro Mangala       Gelson       GK
# 24         25     Inacio Miguel Ferreira Dos\nSantos       Inácio       DF
# 25         26          Laurindo Dilson Maria Aurelio         Depu       FW
# 26         27          Francisco Gonçalves Sacalumbo        Banza       FW
#
#      birthdate    team                            club club_country
# 0   25.07.1994  Angola                  Etoile Carouge       Angola
# 1   24.03.1995  Angola                         Gent KK       Angola
# 2   27.09.1993  Angola                     Valencinnes       Angola
# 3   16.01.2003  Angola              Estrela da Amadora       Angola
# 4   13.03.1998  Angola  Atletico Petroleos de Luanda\n       Angola
# 5   27.09.1997  Angola              Estrela da Amadora       Angola
# 6   10.03.2001  Angola   Atlético Petróleos de Luand\n       Angola
# 7   21.05.2002  Angola                     Casa Pia FC       Angola
# 8   03.07.2002  Angola                          AEK FC       Angola
# 9   13.07.1996  Angola                       Al Wakrah       Angola
# 10  12.10.1999  Angola                Maccabi Tel Aviv       Angola
# 11  30.11.1994  Angola            Oliveira do Hospital       Angola
# 12  05.11.1995  Angola              Atletico petrolios       Angola
# 13  26.02.2000  Angola                      Alanyaspor       Angola
# 14  09.03.2002  Angola                        Cagliari       Angola
# 15  27.03.1990  Angola                        Eyupspor       Angola
# 16  23.04.1998  Angola                      Konyasport       Angola
# 17  08.04.1993  Angola                   Clermont Foot       France
# 18  01.06.1992  Angola           Al Ittihad Alexandria       Angola
# 19  22.09.1995  Angola                     Erzurumspor       Angola
# 20  07.03.1994  Angola  atletico petroleos de luanda\n       Angola
# 21  16.12.1993  Angola  Clube Desportivo 1 de Agosto\n       Angola
# 22  06.03.1999  Angola                    Macabi Haifa       Angola
# 23  08.07.1999  Angola                   GD Interclube       Angola
# 24  12.12.1995  Angola  atletico petroleos de luanda\n       Angola
# 25  08.01.2000  Angola                     Gil Vicente       Angola
# 26  17.12.1998  Angola                      Anorthosis       Angola

# %%
# take a part of the dataframe: rows, columns
# iloc, loc, dot, square brackets

# df.iloc[rows, columns]
df.iloc[0:27, :]
# Out:
#     shirt_no.                                   name  jersey_name position  \
# 0           1         Signori Dominique Nymi António    Dominique       GK
# 1           2          Nurio Domingos Matias Fortuna        Nurio       DF
# 2           3                 Buatu Mananga Jonathan        Buatu       DF
# 3           4                         Keliano Manuel      Keliano       MF
# 4           5           Joaquim Marcos Cunga Balanga       Kinito       DF
# 5           6                        Kialonda Gaspar       Gaspar       DF
# 6           7                    Deivi Miguel Vieira     Gilberto       FW
# 7           8              Benedito Mambuene Mukendi         Beni       MF
# 8           9     Ambrósini António Cabaça\nSalvador         Zini       FW
# 9          10                    Jacinto Muondo Dala       Gelson       FW
# 10         11                    Felicio Mendes Joao       Milson       FW
# 11         12           Aldo Geraldo Manuel Monteiro         Kadu       GK
# 12         13  Corte Real Carneiro Augusto\nDe Jesus  To Carneiro       DF
# 13         14                  Loide Antonio Augusto        Loide       DF
# 14         15           Zito André Sebastiao Luvumbo      Luvumbo       FW
# 15         16                Alfredo Kulembe Ribeiro        Fredy       MF
# 16         17          Bruno L. Pinto De Almeida Paz    Bruno Paz       MF
# 17         18                           Jérémie Bela         Bela       FW
# 18         19                    Cristovao Paciencia     Mabululu       FW
# 19         20       Valdmiro Tualungo Paulo\nLameira      Estrela       MF
# 20         21               Eddie Marcos Melo Afonso        Eddie       DF
# 21         22               Adilson Da Cruz Cipriano        Neblu       GK
# 22         23          Manuel Luis Da Silva Cafumana         Show       MF
# 23         24                Francisco Pedro Mangala       Gelson       GK
# 24         25     Inacio Miguel Ferreira Dos\nSantos       Inácio       DF
# 25         26          Laurindo Dilson Maria Aurelio         Depu       FW
# 26         27          Francisco Gonçalves Sacalumbo        Banza       FW
#
#      birthdate    team                            club club_country
# 0   25.07.1994  Angola                  Etoile Carouge       Angola
# 1   24.03.1995  Angola                         Gent KK       Angola
# 2   27.09.1993  Angola                     Valencinnes       Angola
# 3   16.01.2003  Angola              Estrela da Amadora       Angola
# 4   13.03.1998  Angola  Atletico Petroleos de Luanda\n       Angola
# 5   27.09.1997  Angola              Estrela da Amadora       Angola
# 6   10.03.2001  Angola   Atlético Petróleos de Luand\n       Angola
# 7   21.05.2002  Angola                     Casa Pia FC       Angola
# 8   03.07.2002  Angola                          AEK FC       Angola
# 9   13.07.1996  Angola                       Al Wakrah       Angola
# 10  12.10.1999  Angola                Maccabi Tel Aviv       Angola
# 11  30.11.1994  Angola            Oliveira do Hospital       Angola
# 12  05.11.1995  Angola              Atletico petrolios       Angola
# 13  26.02.2000  Angola                      Alanyaspor       Angola
# 14  09.03.2002  Angola                        Cagliari       Angola
# 15  27.03.1990  Angola                        Eyupspor       Angola
# 16  23.04.1998  Angola                      Konyasport       Angola
# 17  08.04.1993  Angola                   Clermont Foot       France
# 18  01.06.1992  Angola           Al Ittihad Alexandria       Angola
# 19  22.09.1995  Angola                     Erzurumspor       Angola
# 20  07.03.1994  Angola  atletico petroleos de luanda\n       Angola
# 21  16.12.1993  Angola  Clube Desportivo 1 de Agosto\n       Angola
# 22  06.03.1999  Angola                    Macabi Haifa       Angola
# 23  08.07.1999  Angola                   GD Interclube       Angola
# 24  12.12.1995  Angola  atletico petroleos de luanda\n       Angola
# 25  08.01.2000  Angola                     Gil Vicente       Angola
# 26  17.12.1998  Angola                      Anorthosis       Angola

# %%
df.iloc[0:27,[1,5, 6]]
# Out:
#                                      name    team  \
# 0          Signori Dominique Nymi António  Angola
# 1           Nurio Domingos Matias Fortuna  Angola
# 2                  Buatu Mananga Jonathan  Angola
# 3                          Keliano Manuel  Angola
# 4            Joaquim Marcos Cunga Balanga  Angola
# 5                         Kialonda Gaspar  Angola
# 6                     Deivi Miguel Vieira  Angola
# 7               Benedito Mambuene Mukendi  Angola
# 8      Ambrósini António Cabaça\nSalvador  Angola
# 9                     Jacinto Muondo Dala  Angola
# 10                    Felicio Mendes Joao  Angola
# 11           Aldo Geraldo Manuel Monteiro  Angola
# 12  Corte Real Carneiro Augusto\nDe Jesus  Angola
# 13                  Loide Antonio Augusto  Angola
# 14           Zito André Sebastiao Luvumbo  Angola
# 15                Alfredo Kulembe Ribeiro  Angola
# 16          Bruno L. Pinto De Almeida Paz  Angola
# 17                           Jérémie Bela  Angola
# 18                    Cristovao Paciencia  Angola
# 19       Valdmiro Tualungo Paulo\nLameira  Angola
# 20               Eddie Marcos Melo Afonso  Angola
# 21               Adilson Da Cruz Cipriano  Angola
# 22          Manuel Luis Da Silva Cafumana  Angola
# 23                Francisco Pedro Mangala  Angola
# 24     Inacio Miguel Ferreira Dos\nSantos  Angola
# 25          Laurindo Dilson Maria Aurelio  Angola
# 26          Francisco Gonçalves Sacalumbo  Angola
#
#                               club
# 0                   Etoile Carouge
# 1                          Gent KK
# 2                      Valencinnes
# 3               Estrela da Amadora
# 4   Atletico Petroleos de Luanda\n
# 5               Estrela da Amadora
# 6    Atlético Petróleos de Luand\n
# 7                      Casa Pia FC
# 8                           AEK FC
# 9                        Al Wakrah
# 10                Maccabi Tel Aviv
# 11            Oliveira do Hospital
# 12              Atletico petrolios
# 13                      Alanyaspor
# 14                        Cagliari
# 15                        Eyupspor
# 16                      Konyasport
# 17                   Clermont Foot
# 18           Al Ittihad Alexandria
# 19                     Erzurumspor
# 20  atletico petroleos de luanda\n
# 21  Clube Desportivo 1 de Agosto\n
# 22                    Macabi Haifa
# 23                   GD Interclube
# 24  atletico petroleos de luanda\n
# 25                     Gil Vicente
# 26                      Anorthosis

# %%
df.iloc[0:27, [1, 4, 5]]

# %%
df.loc[0:27, ['team', 'club_country']]
# Out:
#        team     club_country
# 0    Angola           Angola
# 1    Angola           Angola
# 2    Angola           Angola
# 3    Angola           Angola
# 4    Angola           Angola
# 5    Angola           Angola
# 6    Angola           Angola
# 7    Angola           Angola
# 8    Angola           Angola
# 9    Angola           Angola
# 10   Angola           Angola
# 11   Angola           Angola
# 12   Angola           Angola
# 13   Angola           Angola
# 14   Angola           Angola
# 15   Angola           Angola
# 16   Angola           Angola
# 17   Angola           France
# 18   Angola           Angola
# 19   Angola           Angola
# 20   Angola           Angola
# 21   Angola           Angola
# 22   Angola           Angola
# 23   Angola           Angola
# 24   Angola           Angola
# 25   Angola           Angola
# 26   Angola           Angola
# 27  Algeria  Arabie Saoudite

# %%
print(df.shape)
df.info()
# Out:
# (624, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   shirt_no.     624 non-null    int64
#  1   name          624 non-null    object
#  2   jersey_name   624 non-null    object
#  3   position      624 non-null    object
#  4   birthdate     624 non-null    object
#  5   team          624 non-null    object
#  6   club          621 non-null    object
#  7   club_country  621 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 39.1+ KB

# %%
df.describe()
# Out:
#         shirt_no.
# count  624.000000
# mean    13.652244
# std      7.612351
# min      1.000000
# 25%      7.000000
# 50%     14.000000
# 75%     20.000000
# max     27.000000

# %%
from datetime import datetime
df['birthdate'] = pd.to_datetime(df['birthdate'], errors='coerce') #format="%Y-%m.%d")#1994-07-25

df['age'] = (datetime.now() - df['birthdate']).dt.days//365
# Out:
# C:\Users\KLAUS\AppData\Local\Temp\ipykernel_15468\4199949391.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['birthdate'] = pd.to_datetime(df['birthdate'], errors='coerce') #format="%Y-%m.%d")#1994-07-25

# %%
df.head()
# Out:
#    shirt_no.                            name jersey_name position  birthdate  \
# 0          1  Signori Dominique Nymi António   Dominique       GK 1994-07-25
# 1          2   Nurio Domingos Matias Fortuna       Nurio       DF 1995-03-24
# 2          3          Buatu Mananga Jonathan       Buatu       DF 1993-09-27
# 3          4                  Keliano Manuel     Keliano       MF 2003-01-16
# 4          5    Joaquim Marcos Cunga Balanga      Kinito       DF 1998-03-13
#
#      team                            club club_country  age
# 0  Angola                  Etoile Carouge       Angola   29
# 1  Angola                         Gent KK       Angola   29
# 2  Angola                     Valencinnes       Angola   30
# 3  Angola              Estrela da Amadora       Angola   21
# 4  Angola  Atletico Petroleos de Luanda\n       Angola   26

# %%
# count number of defenders
df[df.position == 'DF']
# Out:
#      shirt_no.                                   name  jersey_name position  \
# 1            2          Nurio Domingos Matias Fortuna        Nurio       DF
# 2            3                 Buatu Mananga Jonathan        Buatu       DF
# 4            5           Joaquim Marcos Cunga Balanga       Kinito       DF
# 5            6                        Kialonda Gaspar       Gaspar       DF
# 12          13  Corte Real Carneiro Augusto\nDe Jesus  To Carneiro       DF
# ..         ...                                    ...          ...      ...
# 609         13                         Stoppila Sunzu        SUNZU       DF
# 617         21                         Dominic Chanda       CHANDA       DF
# 619         23                          Rodrick Kabwe        KABWE       DF
# 622         26                            Tandi Mwape        MWAPE       DF
# 623         27                   Gift Prosper Mphande      MPHANDE       DF
#
#      birthdate    team                            club club_country  age
# 1   1995-03-24  Angola                         Gent KK       Angola   29
# 2   1993-09-27  Angola                     Valencinnes       Angola   30
# 4   1998-03-13  Angola  Atletico Petroleos de Luanda\n       Angola   26
# 5   1997-09-27  Angola              Estrela da Amadora       Angola   26
# 12  1995-05-11  Angola              Atletico petrolios       Angola   28
# ..         ...     ...                             ...          ...  ...
# 609 1989-06-22  Zambia                   JINAN QINGDAO        Chine   34
# 617 1996-02-26  Zambia                  KABWE WARRIORS       Zambie   28
# 619 1992-11-30  Zambia                        ZAHKO FC         Irak   31
# 622 1996-07-20  Zambia                      TP MAZEMBE        Congo   27
# 623 2003-12-02  Zambia                             NaN          NaN   20
#
# [206 rows x 9 columns]

# %% [markdown]
# - Grouping Data

# %%
# Aggregate Data, Apply Functions, Data Exploration
# groupby

# %%
df.groupby('team')['age'].max().sort_values(ascending = False)
# Out:
# team
# Mozambique       40
# Algeria          38
# Cap Vert         38
# Côte D'Ivoire    37
# Guinea           37
# Maroc            36
# Burkina Faso     36
# South Africa     35
# Egypt            35
# Gambia           35
# Ghana            35
# Namibia          35
# Tunisie          34
# Senegal          34
# Guinea Bissau    34
# Angola           34
# Eq. Guinea       34
# Zambia           34
# Mauritania       32
# Mali             32
# Congo Dr         32
# Cameroon         32
# Nigeria          31
# Tanzania         31
# Name: age, dtype: int64

# %%
df.groupby('team')['age'].min().sort_values(ascending = True)
# Out:
# team
# Cameroon         17
# Guinea           19
# Tanzania         19
# Mauritania       19
# Maroc            19
# Guinea Bissau    19
# Gambia           19
# Zambia           19
# Eq. Guinea       20
# Côte D'Ivoire    20
# Burkina Faso     20
# Mozambique       20
# Senegal          20
# South Africa     20
# Ghana            21
# Mali             21
# Namibia          21
# Angola           21
# Algeria          21
# Tunisie          22
# Cap Vert         22
# Congo Dr         23
# Nigeria          23
# Egypt            24
# Name: age, dtype: int64

# %%
df[df.age == 40]
# Out:
#      shirt_no.                  name jersey_name position  birthdate  \
# 425          7  Elias Gaspar Pelembe     Pelembe       MF 1983-11-13
#
#            team club club_country  age
# 425  Mozambique  UDS   Mozambique   40

# %%
df.age.min()
# Out:
# 17

# %%
df[df.age == df.age.min()]
# Out:
#      shirt_no.                     name jersey_name position  birthdate  \
# 106         27  Doualla Wilfried Nathan     Doualla       MF 2006-06-15
#
#          team             club club_country  age
# 106  Cameroon  Victoria United     Cameroun   17

# %% [markdown]
# - Data Types

# %%
df.info()

# %%
# handling missing values

# isna() isnull() notnull()

df.isna().sum()
# Out:
# shirt_no.       0
# name            0
# jersey_name     0
# position        0
# birthdate       0
# team            0
# club            3
# club_country    3
# age             0
# dtype: int64

# %%
# for those players without a club. 
df.club.fillna('Free Agents', inplace=True)

# %% [markdown]
# after executing this line of code, any missing values in the 'club' column of the DataFrame df will be replaced with 'Free Agents', and the changes will be applied directly to df

# %%
df.isna().sum()

# %%
df.club_country.fillna('No Clubs', inplace=True)

# %%
df.isnull().sum()
# Out:
# shirt_no.       0
# name            0
# jersey_name     0
# position        0
# birthdate       0
# team            0
# club            0
# club_country    0
# age             0
# dtype: int64

# %%
# duplicate values

df[df.duplicated(subset='jersey_name')]
# Out:
#      shirt_no.                     name jersey_name position  birthdate  \
# 23          24  Francisco Pedro Mangala      Gelson       GK 1999-08-07
# 65          13           Mohamed Konate      KONATE       FW 1997-12-12
# 166         10             Karim Konate      KONATE       FW 2004-03-21
# 174         18          Ibrahim Sangare     SANGARE       MF 1997-02-12
# 332         20              Mory Konate      KONATE       MF 1993-11-15
# 344          7           Moussa Doumbia     DOUMBIA       FW 1994-08-15
# 352         15           Mamadou Fofana      FOFANA       DF 1998-01-21
# 511         22      Abdou Lakhad Diallo      DIALLO       DF 1996-04-05
# 512         23                Mory Diaw        DIAW       GK 1993-06-22
# 604          8   Sailas Lubambo Musonda     MUSONDA       MF 1995-01-03
# 606         10     Fashon Junior Sakala      SAKALA       FW 1997-03-14
# 608         12    Emmanuel Junior Banda       BANDA       MF 1997-09-29
# 621         25          Kennedy Musonda     MUSONDA       FW 1994-12-22
#
#               team                    club      club_country  age
# 23          Angola           GD Interclube            Angola   24
# 65    Burkina Faso           AKHMAT GROZNY            Russie   26
# 166  Côte D'Ivoire  FC RED BULL SALZBURG\n          Autriche   20
# 174  Côte D'Ivoire       Nottingham Forest        Angleterre   27
# 332         Guinea             KV MECHELEN          Belgique   30
# 344           Mali          AL ADALAH CLUB  Arabie\nSaoudite   29
# 352           Mali               Amiens SC            France   26
# 511        Senegal                AL Arabi             Qatar   28
# 512        Senegal        Clermont Ferrand            France   30
# 604         Zambia                SILKBORG          Danemark   29
# 606         Zambia           Al Fayha club   Arabie Saoudite   27
# 608         Zambia               REIJKA FC           Croatie   26
# 621         Zambia                YANGA SC          Tanzanie   29

# %%
df[df.duplicated(subset='birthdate')]
# Out:
#      shirt_no.                                       name   jersey_name  \
# 31           5                                Ahmed Touba         Touba
# 114          8               João Paulo Moreira Fernandes     Fernandes
# 152         22                     Chancel Mangulu Mbemba      C.MBEMBA
# 167         11         Jean Philippe Nils Stephan\nKrasso        KRASSO
# 169         13                               Jeremie Boga          BOGA
# 218          8                          Jannick Buyla Sam  YANNICK B.S.
# 240          8                               Ebrima Adams      E. Adams
# 242         10                                Musa Barrow     M. Barrow
# 256         24                              Ebrima Darboe     E. Darboe
# 298         13                        Carlos Mendes Gomes  CARLOS GOMES
# 317          5                           Mouctar Diakhaby   M. DIAKHABY
# 318          6                             Amadou Diawara     A.DIAWARA
# 347         10                              Yves Bissouma      BISSOUMA
# 355         18                 Youssoufou Niakate Niakate     Y NIAKATE
# 358         21                               Adama Traore          NOSS
# 366          2                              Achraf Hakimi        HAKIMI
# 386         22                           El Mehdi Benabid       BENABID
# 398          7                                Ba Al Hadji          E.BA
# 422          4                        Feliciano Joao Jone      Nene III
# 428         10               Clesio Palmirim David Bauque        Clesio
# 440         22  Ivane Carminio Francisco\nOficial Urrubal    C. Urrubal
# 444          3                           Ananias Gebhardt      Gebhardt
# 449          8                            Uetuuru Kambato       Kambato
# 501         12                                 Fode Ballo       B.TOURE
# 507         18                               Ismaila Sarr          SARR
# 510         21                            Youssouf Sabaly        SABALY
# 524          8                         Jayden Oswin Adams         Adams
# 530         14                              Mothobi Mvala         Mvala
# 533         17                      Lerato Zakhele Lepasa        Lepasa
# 535         19                 Nkosinathi Emmanuel Sibisi        Sibisi
# 569         27                     Mohamed Ali Omar Sagaf       Mohamed
# 572          3                       Montassar Omar Talbi         TALBI
# 579         10                           Anis Ben Slimane   BEN SLIMANE
# 582         13                               Hamza Jlassi        JLASSI
# 590         21                             Wajdi Kechrida      KECHRIDA
# 596         27                              Achouri Elyes       ACHOURI
# 599          3                          Benedict Chepeshi      CHEPESHI
# 600          4                   Frankie Chisenga Musonda       MUSONDA
# 607         11                               Rally Bwalya        BWALYA
# 612         16                           Lawrence Mulenga       MULENGA
# 615         19                          Fredrick Mulambia      MULAMBIA
# 622         26                                Tandi Mwape         MWAPE
#
#     position  birthdate           team                           club  \
# 31        DF 1998-03-13        Algeria                      U.S.Lecce
# 114       MF 1998-05-26       Cap Vert               SHERIFF TIRASPOL
# 152       DF 1994-08-08       Congo Dr            Olympique Marseille
# 167       FW 1997-07-17  Côte D'Ivoire     Etoile Rouge de Belgrade\n
# 169       FW 1997-03-01  Côte D'Ivoire                        OGC NCE
# 218       MF 1998-06-10     Eq. Guinea                    SD Logroñés
# 240       MF 1996-01-15         Gambia                Cardiff City FC
# 242       FW 1998-11-14         Gambia                      al taawon
# 256       MF 2001-06-06         Gambia                   LASK LINZ FC
# 298       MF 1998-11-14  Guinea Bissau                         BOLTON
# 317       DF 1996-12-19         Guinea                     FC VALENCE
# 318       MF 1997-07-17         Guinea                 RSC ANDERLECHT
# 347       MF 1996-08-30           Mali                      TOTTENHAM
# 355       FW 1992-12-16           Mali                    Bani Yas FC
# 358       MF 1995-06-28           Mali               Hull City Tigers
# 366       DF 1998-04-11          Maroc                            PSG
# 386       GK 1998-01-24          Maroc                         ASFAR
# 398       MF 1993-05-03     Mauritania                  FC Nouadhibou
# 422       DF 1996-11-15     Mozambique                            ABB
# 428       FW 1994-11-10     Mozambique                       FC HONKA
# 440       GK 1997-03-01     Mozambique                            ABB
# 444       DF 1988-08-09        Namibia                      Baroka FC
# 449       FW 1998-01-24        Namibia               African Stars FC
# 501       DF 1997-03-01        Senegal                         FULHAM
# 507       FW 1998-02-25        Senegal                      Marseille
# 510       DF 1993-05-03        Senegal                  BETIS SEVILLE
# 524       MF 2001-05-05   South Africa                 Stellenboch FC
# 530       DF 1994-06-14   South Africa           Mamelodi Sundowns FC
# 533       FW 1997-03-01   South Africa                Orlando Pirates
# 535       DF 1995-09-22   South Africa                Orlando Pirates
# 569       FW 1997-12-11       Tanzania                Boreham wood fc
# 572       DF 1998-05-26        Tunisie                     FC LORIENT
# 579       MF 2001-03-16        Tunisie               SHEFFIELD UNITED
# 582       DF 1991-09-29        Tunisie        Etoile Sportie du Sahel
# 590       DF 1995-05-11        Tunisie                   Atromitos FC
# 596       FW 1999-10-02        Tunisie                  FC COPENHAGUE
# 599       DF 1996-10-06         Zambia                  RED ARROWS FC
# 600       DF 1997-12-12         Zambia                       ARYER FC
# 607       MF 1995-05-29         Zambia           Sekhukhune United FC
# 612       GK 1996-08-21         Zambia  Power Dynamos Football Club\n
# 615       MF 1999-10-07         Zambia               Power Dynamos FC
# 622       DF 1996-07-20         Zambia                     TP MAZEMBE
#
#                                           club_country  age
# 31                                              Italie   26
# 114                                           Moldavie   25
# 152                                             France   29
# 167                                             Serbie   26
# 169                                             France   27
# 218                                            Espagne   25
# 240                                         Angleterre   28
# 242                                    Arabie Saoudite   25
# 256                                           Autriche   22
# 298                                         Angleterre   25
# 317                                            Espagne   27
# 318                                           Belgique   26
# 347                                         Angleterre   27
# 355                               Émirats arabes\nunis   31
# 358                                         Angleterre   28
# 366                                             France   26
# 386  ASSOCIATION SPORTIVE\nDES FORCES ARMÉES ROYA\n...   26
# 398                                         Mauritanie   30
# 422                                         Mozambique   27
# 428                                           Finlande   29
# 440                                         Mozambique   27
# 444                                     Afrique Du Sud   35
# 449                                            Namibie   26
# 501                                         Angleterre   27
# 507                                             France   26
# 510                                            Espagne   30
# 524                                     Afrique Du Sud   22
# 530                                    Afrique\nDu Sud   29
# 533                                    Afrique Du\nSud   27
# 535                                    Afrique Du\nSud   28
# 569                                      Royaume-\nUni   26
# 572                                             France   25
# 579                                         Angleterre   23
# 582                                            Tunisie   32
# 590                                              Grèce   28
# 596                                           Danemark   24
# 599                                             Zambie   27
# 600                                             Écosse   26
# 607                                    Afrique\nDu Sud   28
# 612                                             Zambie   27
# 615                                             Zambie   24
# 622                                              Congo   27

# %%
df[df.birthdate == '1996-07-20']
# Out:
#      shirt_no.                  name jersey_name position  birthdate  \
# 85           6  Michel Kemen Olivier       KEMEN       MF 1996-07-20
# 622         26           Tandi Mwape       MWAPE       DF 1996-07-20
#
#          team         club club_country  age
# 85   Cameroon  Kayserispor      Turquie   27
# 622    Zambia   TP MAZEMBE        Congo   27

# %%
df['club'] = df['club'].str.strip()

# %%
df[df.birthdate == '1998-03-13']
# Out:
#     shirt_no.                          name jersey_name position  birthdate  \
# 4           5  Joaquim Marcos Cunga Balanga      Kinito       DF 1998-03-13
# 31          5                   Ahmed Touba       Touba       DF 1998-03-13
#
#        team                          club club_country  age
# 4    Angola  Atletico Petroleos de Luanda       Angola   26
# 31  Algeria                     U.S.Lecce       Italie   26

# %%
df.age.describe()
# Out:
# count    624.000000
# mean      26.919872
# std        3.814308
# min       17.000000
# 25%       24.000000
# 50%       27.000000
# 75%       29.000000
# max       40.000000
# Name: age, dtype: float64

# %% [markdown]
# - Variance: Variance is the average of the squared differences from the Mean. It gives an idea of how much the data values differ from the mean. Mathematically, it's calculated as follows:
#
#   - Calculate the mean (average) of the dataset.
#    - Subtract the mean from each data point, square the result.
#     - Find the average of those squared differences.

# %%
age_list = df.age.tolist()

# %%
df.age.mean()
# Out:
# 26.919871794871796

# %%
age_list
# Out:
# [29,
#  29,
#  30,
#  21,
#  26,
#  26,
#  22,
#  21,
#  22,
#  27,
#  24,
#  29,
#  28,
#  24,
#  21,
#  34,
#  25,
#  30,
#  32,
#  28,
#  29,
#  30,
#  24,
#  24,
#  28,
#  23,
#  25,
#  33,
#  32,
#  28,
#  24,
#  26,
#  25,
#  33,
#  32,
#  32,
#  34,
#  25,
#  27,
#  35,
#  24,
#  22,
#  27,
#  21,
#  23,
#  29,
#  27,
#  29,
#  27,
#  38,
#  25,
#  23,
#  29,
#  29,
#  24,
#  26,
#  21,
#  21,
#  23,
#  21,
#  26,
#  22,
#  28,
#  22,
#  25,
#  26,
#  32,
#  22,
#  27,
#  27,
#  24,
#  25,
#  27,
#  24,
#  30,
#  20,
#  36,
#  31,
#  25,
#  20,
#  28,
#  26,
#  29,
#  22,
#  26,
#  27,
#  30,
#  28,
#  25,
#  32,
#  29,
#  31,
#  24,
#  20,
#  26,
#  31,
#  27,
#  23,
#  24,
#  21,
#  29,
#  27,
#  20,
#  28,
#  23,
#  21,
#  17,
#  38,
#  35,
#  29,
#  31,
#  23,
#  30,
#  25,
#  25,
#  22,
#  30,
#  33,
#  27,
#  32,
#  25,
#  27,
#  27,
#  29,
#  24,
#  24,
#  33,
#  33,
#  27,
#  29,
#  24,
#  22,
#  27,
#  30,
#  29,
#  23,
#  28,
#  29,
#  26,
#  27,
#  28,
#  25,
#  29,
#  26,
#  32,
#  24,
#  25,
#  32,
#  26,
#  29,
#  28,
#  26,
#  29,
#  27,
#  26,
#  26,
#  30,
#  23,
#  21,
#  28,
#  32,
#  23,
#  28,
#  23,
#  27,
#  28,
#  20,
#  26,
#  33,
#  27,
#  20,
#  36,
#  33,
#  31,
#  27,
#  28,
#  26,
#  24,
#  29,
#  37,
#  22,
#  26,
#  27,
#  25,
#  32,
#  35,
#  28,
#  30,
#  29,
#  33,
#  30,
#  26,
#  30,
#  31,
#  30,
#  29,
#  26,
#  26,
#  30,
#  35,
#  31,
#  29,
#  26,
#  30,
#  32,
#  24,
#  35,
#  25,
#  27,
#  24,
#  27,
#  23,
#  22,
#  26,
#  28,
#  23,
#  28,
#  27,
#  25,
#  24,
#  34,
#  25,
#  20,
#  28,
#  22,
#  30,
#  25,
#  21,
#  22,
#  23,
#  25,
#  30,
#  31,
#  35,
#  29,
#  25,
#  34,
#  31,
#  28,
#  23,
#  28,
#  30,
#  25,
#  24,
#  22,
#  29,
#  27,
#  27,
#  25,
#  28,
#  26,
#  24,
#  19,
#  24,
#  22,
#  25,
#  22,
#  29,
#  29,
#  27,
#  31,
#  24,
#  35,
#  26,
#  30,
#  25,
#  22,
#  26,
#  32,
#  34,
#  25,
#  27,
#  26,
#  25,
#  26,
#  27,
#  25,
#  29,
#  29,
#  24,
#  24,
#  27,
#  29,
#  21,
#  23,
#  28,
#  25,
#  34,
#  26,
#  19,
#  30,
#  22,
#  27,
#  26,
#  30,
#  29,
#  20,
#  26,
#  25,
#  23,
#  26,
#  26,
#  28,
#  21,
#  28,
#  28,
#  29,
#  33,
#  20,
#  27,
#  30,
#  25,
#  27,
#  37,
#  30,
#  30,
#  22,
#  27,
#  26,
#  25,
#  28,
#  27,
#  21,
#  26,
#  20,
#  26,
#  19,
#  22,
#  25,
#  32,
#  22,
#  28,
#  30,
#  24,
#  34,
#  30,
#  33,
#  19,
#  29,
#  32,
#  23,
#  26,
#  27,
#  24,
#  29,
#  27,
#  28,
#  27,
#  27,
#  23,
#  23,
#  21,
#  26,
#  29,
#  29,
#  31,
#  28,
#  24,
#  28,
#  28,
#  26,
#  22,
#  24,
#  21,
#  21,
#  32,
#  26,
#  26,
#  27,
#  28,
#  34,
#  31,
#  24,
#  31,
#  26,
#  23,
#  34,
#  36,
#  22,
#  27,
#  22,
#  30,
#  24,
#  27,
#  30,
#  23,
#  26,
#  19,
#  22,
#  29,
#  20,
#  31,
#  29,
#  25,
#  26,
#  29,
#  26,
#  31,
#  30,
#  26,
#  26,
#  24,
#  26,
#  30,
#  23,
#  27,
#  32,
#  27,
#  24,
#  22,
#  25,
#  22,
#  30,
#  29,
#  25,
#  25,
#  30,
#  19,
#  28,
#  25,
#  27,
#  28,
#  27,
#  26,
#  28,
#  40,
#  29,
#  29,
#  29,
#  26,
#  20,
#  29,
#  25,
#  30,
#  24,
#  35,
#  29,
#  27,
#  23,
#  28,
#  27,
#  26,
#  35,
#  33,
#  35,
#  28,
#  33,
#  22,
#  33,
#  26,
#  24,
#  21,
#  32,
#  28,
#  30,
#  32,
#  27,
#  24,
#  28,
#  24,
#  31,
#  30,
#  23,
#  27,
#  29,
#  25,
#  27,
#  26,
#  23,
#  31,
#  30,
#  31,
#  26,
#  25,
#  27,
#  24,
#  26,
#  25,
#  28,
#  28,
#  28,
#  28,
#  26,
#  27,
#  27,
#  24,
#  30,
#  27,
#  23,
#  23,
#  29,
#  23,
#  32,
#  32,
#  34,
#  31,
#  22,
#  34,
#  27,
#  31,
#  30,
#  27,
#  23,
#  24,
#  25,
#  32,
#  21,
#  26,
#  27,
#  28,
#  30,
#  28,
#  30,
#  22,
#  20,
#  25,
#  21,
#  32,
#  29,
#  27,
#  27,
#  32,
#  28,
#  22,
#  22,
#  23,
#  29,
#  35,
#  20,
#  25,
#  29,
#  34,
#  32,
#  27,
#  31,
#  28,
#  28,
#  27,
#  30,
#  30,
#  28,
#  30,
#  24,
#  22,
#  20,
#  27,
#  26,
#  23,
#  25,
#  31,
#  20,
#  19,
#  31,
#  26,
#  31,
#  29,
#  26,
#  28,
#  23,
#  27,
#  28,
#  28,
#  22,
#  26,
#  24,
#  21,
#  29,
#  28,
#  21,
#  26,
#  28,
#  30,
#  25,
#  31,
#  24,
#  23,
#  33,
#  25,
#  30,
#  23,
#  32,
#  34,
#  32,
#  27,
#  32,
#  27,
#  28,
#  23,
#  26,
#  25,
#  28,
#  31,
#  31,
#  30,
#  23,
#  22,
#  24,
#  30,
#  27,
#  27,
#  26,
#  19,
#  27,
#  27,
#  29,
#  23,
#  27,
#  28,
#  26,
#  34,
#  24,
#  27,
#  27,
#  32,
#  22,
#  24,
#  25,
#  28,
#  24,
#  31,
#  23,
#  29,
#  27,
#  20]

# %%
df.groupby('team')['age'].min().sort_values(ascending=True)
# Out:
# team
# Cameroon         17
# Guinea           19
# Tanzania         19
# Mauritania       19
# Maroc            19
# Guinea Bissau    19
# Gambia           19
# Zambia           19
# Eq. Guinea       20
# Côte D'Ivoire    20
# Burkina Faso     20
# Mozambique       20
# Senegal          20
# South Africa     20
# Ghana            21
# Mali             21
# Namibia          21
# Angola           21
# Algeria          21
# Tunisie          22
# Cap Vert         22
# Congo Dr         23
# Nigeria          23
# Egypt            24
# Name: age, dtype: int64

# %%
age_no_var = [29, 29, 29, 29, 29, 29, 29, 29, 29]
import numpy as np
data = np.array([age_no_var])
no_var = np.var(data)
print(no_var)
# Out:
# 0.0

# %%
data = np.array([age_list])
var = np.var(data)
print(var)
# Out:
# 14.525630752794214

# %% [markdown]
# - What is standard deviation?
#
#     A measure of how dispersed the data is in relation to the mean
#     - Step 1: Find the mean.
#     - Step 2: For each data point, find the square of its distance to the mean.
#     - Step 3: Sum the values from Step 2.
#     - Step 4: Divide by the number of data points.
#     - Step 5: Take the square root

# %%
df.age.std()
# Out:
# 3.8143081118310365

# %%
df.age.hist(bins=10)
# Out:
# <Axes: >

# %% [markdown]
# -  1 Standard Deviation from the Mean: 68 percent.
# -  2 Standard Deviations from the Mean: 95 percent.
# -  3 Standard Deviations from the Mean: 99.7 percent.

# %%
# outliers 

mean = round(df.age.mean(), 2)
std = round(df.age.std(), 2)

# %%
print(mean)
print(std)
# Out:
# 26.92
# 3.81

# %%
one_std = (mean+std, mean-std)

# %%
one_std
# Out:
# (30.73, 23.110000000000003)

# %%
two_std = (mean+(std*2), mean-(std*2))

# %%
two_std
# Out:
# (34.54, 19.3)

# %%
three_std = (mean+(std*3), mean-(std*3))

# %%
three_std
# Out:
# (38.35, 15.490000000000002)

# %%
def remove_outliers(df, column, threshold=3):
    mean = df[column].mean()
    std_dev = df[column].std()
    
    lower_bound = mean - threshold * std_dev #PEMDAS
    upper_bound = mean + threshold * std_dev
    # remove outliers
    
    df = df[(df[column]>= lower_bound) & (df[column]<= upper_bound)]
    return df

# %%
df_cleaned = remove_outliers(df, 'age', 2)

# %%
df_cleaned.shape
# Out:
# (596, 9)

# %%
removed_rows = df[~df.index.isin(df_cleaned.index)]

# %%
removed_rows
# Out:
#      shirt_no.                                name   jersey_name position  \
# 39          13                       Islam Slimani       Slimani       FW
# 49          23               Adi-Rais Cobos Mbolhi          RAIS       GK
# 76          24                         Adama Guira         GUIRA       MF
# 106         27             Doualla Wilfried Nathan       Doualla       MF
# 107          1             Josimar José Évora Dias       Vozinha       GK
# 108          2          Ianique Dos Santos Tavares       Stopira       DF
# 171         15                    Max Alain Gradel    MAX GRADEL       FW
# 179         23                   Badra Ali Sangare     BADRA ALI       GK
# 185          2                Aly Gabr Gabr Mossad      ALI GABR       DF
# 199         16  Mohamed Elsayed Mohamed\nElshenawy   M.ELSHENAWY       GK
# 206         23   Mohamed Kotb Kotb Abou Gabal\nAli       GABASKI       GK
# 233          1                          Jobe Modou        M.Jobe       GK
# 252         20                      Yankuba Minteh     Y. Minteh       FW
# 262          3                 Denis Frimpong Odoi          ODOI       DF
# 289          3                Franculino Gluda Dju    FRANCULINO       FW
# 313          1                           Aly Keita      A. KEITA       GK
# 326         14                         Karim Cisse      K. CISSE       MF
# 337         25                       Facinet Conte      F. CONTE       FW
# 377         13                    Yunis Abdelhamid    ABDELHAMID       DF
# 387         23                  Bilal El Khannouss  El Khannouss       MF
# 417         26                    Oumar Jacky Ngom          NGOM       MF
# 425          7                Elias Gaspar Pelembe       Pelembe       MF
# 435         17                   Edson Andre Sitoe         Mexer       DF
# 442          1                       Loydt Kazapua       Kazapua       GK
# 444          3                    Ananias Gebhardt      Gebhardt       DF
# 527         11                        Themba Zwane         Zwane       FW
# 551          9            Cyprian Thobias Kachwele      KACHWELE       DF
# 601          5                Changa Miguel Chaiwa        CHAIWA       MF
#
#      birthdate           team                    club     club_country  age
# 39  1988-06-18        Algeria  Coritiba Football Club           Brésil   35
# 49  1986-04-25        Algeria            CRBelouizdad          Algérie   38
# 76  1988-04-24   Burkina Faso            RACING RIOJA          Espagne   36
# 106 2006-06-15       Cameroon         Victoria United         Cameroun   17
# 107 1986-03-06       Cap Vert              AS Trencin         slovaque   38
# 108 1988-05-20       Cap Vert       Boavista da Praia         Cap Vert   35
# 171 1987-11-30  Côte D'Ivoire         GAZIANTEP SPORT          Turquie   36
# 179 1986-05-30  Côte D'Ivoire    Sekhukhune United FC  Afrique\nDu Sud   37
# 185 1989-01-01          Egypt             Pyramids FC           Égypte   35
# 199 1988-12-18          Egypt              Al Ahly SC           Égypte   35
# 206 1989-01-29          Egypt           National Bank           Égypte   35
# 233 1988-10-27         Gambia              MUSANZE FC           Rwanda   35
# 252 2004-07-22         Gambia               FEYENOORD         Pays-Bas   19
# 262 1988-05-27          Ghana          Club Brugge KV         Belgique   35
# 289 2004-06-28  Guinea Bissau          FC Midtjylland         Danemark   19
# 313 1986-08-12         Guinea              Ostersunds            Suède   37
# 326 2004-11-14         Guinea        AS SAINT ETIENNE           France   19
# 337 2005-03-24         Guinea               SC BASTIA           France   19
# 377 1987-09-28          Maroc        STADE RENNAIS FC           France   36
# 387 2004-10-05          Maroc            K.R.C. Genk.         Belgique   19
# 417 2004-09-03     Mauritania                  FC PAU           France   19
# 425 1983-11-13     Mozambique                     UDS       Mozambique   40
# 435 1988-08-09     Mozambique             Bandirmapor          Turquie   35
# 442 1989-03-25        Namibia           Chippa United   Afrique Du Sud   35
# 444 1988-08-09        Namibia               Baroka FC   Afrique Du Sud   35
# 527 1989-03-08   South Africa    Mamelodi Sundowns FC  Afrique\nDu Sud   35
# 551 2005-02-15       Tanzania                 AZAM FC         Tanzanie   19
# 601 2004-07-06         Zambia          BSC YOUNG BOYS           Suisse   19

# %%
# Treating outliers using the IQR (interquartile range)
import pandas as pd
path = r"C:\Users\KLAUS\Desktop\JUPYTER\ALTSCHOOL-DS\workspace\Downloaded files\datasets\winequality-red.csv"
wine_data = pd.read_csv(path)

wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wine_data.info()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# checking for outliers
plt.figure(figsize= (18, 20)) # set figure size
for i in range(len(wine_data.columns)):
    plt.subplot(4, 3, i+1) # creates a subplot
    sns.boxplot(x = wine_data.iloc[:, i])
    plt.xlabel(wine_data.columns[i], size=15)

# %%
print(wine_data['sulphates'].quantile(0.25))
print(wine_data['sulphates'].quantile(0.75))

# %%
wine_data['sulphates'].plot(kind='density')

# %%
def Outliers(df, col):
    IQ1 = df[col].quantile(0.25)
    IQ3 = df[col].quantile(0.75)
    IQR = IQ3 - IQ1
    
    lower_bound = IQ1 - 1.5 * IQR
    upper_bound = IQ3 + 1.5 * IQR
    index = df.index[(df[col] < lower_bound) | (df[col] > upper_bound)]
    return index

# %%
wine_data.index

# %%
wine_data.shape

# %%
index = []
for i in wine_data.columns:
    index.extend(Outliers(wine_data, i))
index = set(index)
#print(index)
print(f'Total number of outliers are {len(index)}')

# dropping all the outliers
wine_data.drop(index, inplace=True, axis=0)
wine_data.shape

# %%
wine_data.columns

# %%
# !pip install scipy

# %%
# 3. using the z-score

from scipy import stats
z_scores = stats.zscore(wine_data['chlorides'])

# %%
print(z_scores)

# %%
threshold = 0.5

df_filtered = wine_data['chlorides'][(z_scores < threshold)]

# %%
df_filtered

# %%
plt.figure(figsize= (18, 20)) # set figure size
for i in range(len(wine_data.columns)):
    plt.subplot(4, 3, i+1) # creates a subplot
    sns.kdeplot(x = wine_data.iloc[:, i])
    plt.xlabel(wine_data.columns[i], size=15)
