# %%
import pandas as pd

# %%
import numpy as np

# %%
#data
list_df = [[32, 'Portugal', 94], [30, 'Argentina', 93], [25, 'Brazil', 92]]

# %%
#index
index = ['Cristiano Ronaldo', 'Lionel Messi', 'Neymer']

# %%
columns = ['Age', 'Natinality', 'Overall']

# %%
# create a dataframe
pd.DataFrame(data = list_df, index= index, columns = columns)
# Out:
#                    Age Natinality  Overall
# Cristiano Ronaldo   32   Portugal       94
# Lionel Messi        30  Argentina       93
# Neymer              25     Brazil       92

# %%
dict_df = {'Age': [32, 30, 25], 'Nationality': ['Portugal', 'Argentina', 'Brazil'], 'Overall':[93,92,90]}

index = ['Cristiano Ronaldo', 'Lionel Messi', 'Neymer']

pd.DataFrame(dict_df, index=index)
# Out:
#                    Age Nationality  Overall
# Cristiano Ronaldo   32    Portugal       93
# Lionel Messi        30   Argentina       92
# Neymer              25      Brazil       90

# %%
array_df = np.array([[32, 'Portugal', 94], [30, 'Argentina', 93], [25, 'Brazil', 92]])

index = ['Cristiano Ronaldo', 'Lionel Messi', 'Neymer']

columns = ['Age', 'Natinality', 'Overall']
pd.DataFrame(data = array_df, index= index, columns = columns)
# Out:
#                   Age Natinality Overall
# Cristiano Ronaldo  32   Portugal      94
# Lionel Messi       30  Argentina      93
# Neymer             25     Brazil      92

# %%
array_df
# Out:
# array([['32', 'Portugal', '94'],
#        ['30', 'Argentina', '93'],
#        ['25', 'Brazil', '92']], dtype='<U11')

# %%
#looping through a dataframe

# %%
file = 'fifa.csv'

# %%
# loading data from csv
df = pd.read_csv(file, index_col = 'Name')
# Out:
# C:\Users\KLAUS\AppData\Local\Temp\ipykernel_16496\3363806840.py:2: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, index_col = 'Name')

# %%
df.head()
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# L. Messi           95           95        96       77      ...        88
# Neymar             82           95        92       75      ...        81
# L. Suárez          60           91        83       77      ...        83
# M. Neuer           35           48        70       15      ...        55
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# L. Messi              85             26           87      73
# Neymar                80             33           90      78
# L. Suárez             87             38           77      89
# M. Neuer              25             11           61      44
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# L. Messi                   28       59      90      85                     RW
# Neymar                     24       53      80      83                     LW
# L. Suárez                  45       80      84      88                     ST
# M. Neuer                   10       83      70      11                     GK
#
# [5 rows x 38 columns]

# %%
df.shape
# Out:
# (17981, 38)

# %%
df.tail()
# Out:
#                Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# A. Kelsey       17     England       46       24         16      38
# B. Richardson   47     England       46       25         44      35
# J. Young        17    Scotland       46       66         26      60
# J. Lundstram    18     England       46       57         46      58
# L. Sackey       18       Ghana       46       48         52      49
#
#               Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                   ...
# A. Kelsey      26           12        23       14      ...        19
# B. Richardson  44           22        44       11      ...        12
# J. Young       77           41        50       28      ...        42
# J. Lundstram   74           43        45       34      ...        49
# L. Sackey      47           32        33       19      ...        31
#
#               Shot power Sliding tackle Sprint speed Stamina Standing tackle  \
# Name
# A. Kelsey         19             10           32      28              11
# B. Richardson     13             13           25      32              12
# J. Young          42             14           51      33              17
# J. Lundstram      43             47           58      49              48
# L. Sackey         21             43           49      55              44
#
#               Strength  Vision Volleys Preferred Positions
# Name
# A. Kelsey       50      26       6                     GK
# B. Richardson   47      17      12                     GK
# J. Young        32      37      33                     ST
# J. Lundstram    46      51      25                     CM
# L. Sackey       67      22      19                  ST CB
#
# [5 rows x 38 columns]

# %%
df.iloc[99]
# Out:
# Age                            23
# Nationality               Germany
# Overall                        84
# Acceleration               76
# Aggression                 48
# Agility                    81
# Balance                    75
# Ball control               87
# Composure                  81
# Crossing                   83
# Curve                      78
# Dribbling                  88
# Finishing                  78
# Free kick accuracy         75
# GK diving                  11
# GK handling                13
# GK kicking                  5
# GK positioning             13
# GK reflexes                 8
# Heading accuracy           65
# Interceptions              36
# Jumping                    76
# Long passing               77
# Long shots                 81
# Marking                    25
# Penalties                  63
# Positioning                79
# Reactions                  83
# Short passing              84
# Shot power                 86
# Sliding tackle             26
# Sprint speed               79
# Stamina                    68
# Standing tackle            35
# Strength                   67
# Vision                     84
# Volleys                    84
# Preferred Positions    LM CAM LW
# Name: J. Draxler, dtype: object

# %%
df.iloc[9:100]
# Out:
#               Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# G. Higuaín     29   Argentina       90       78         50      75
# Sergio Ramos   31       Spain       90       75         84      79
# K. De Bruyne   26     Belgium       89       76         68      80
# T. Courtois    25     Belgium       89       46         23      61
# A. Sánchez     28       Chile       89       88         80      90
# ...           ...         ...      ...          ...        ...     ...
# A. Laporte     23      France       84       68         72      49
# D. Alli        21     England       84       77         84      74
# S. Mané        25     Senegal       84       94         73      89
# Carvajal       25       Spain       84       76         81      82
# J. Draxler     23     Germany       84       76         48      81
#
#              Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                  ...
# G. Higuaín    69           85        86       68      ...        75
# Sergio Ramos  60           84        80       66      ...        78
# K. De Bruyne  75           87        84       90      ...        90
# T. Courtois   45           23        52       14      ...        32
# A. Sánchez    87           87        86       80      ...        81
# ...              ...          ...       ...      ...  ...           ...
# A. Laporte    55           71        74       58      ...        73
# D. Alli       62           85        86       68      ...        83
# S. Mané       85           84        78       72      ...        77
# Carvajal      79           83        74       83      ...        81
# J. Draxler    75           87        81       83      ...        84
#
#              Shot power Sliding tackle Sprint speed Stamina Standing tackle  \
# Name
# G. Higuaín       88             18           80      72              22
# Sergio Ramos     79             91           77      84              89
# K. De Bruyne     85             40           75      87              51
# T. Courtois      36             16           52      38              18
# A. Sánchez       84             35           84      85              39
# ...                 ...            ...          ...     ...             ...
# A. Laporte       70             85           70      71              88
# D. Alli          77             57           76      89              63
# S. Mané          77             38           92      82              35
# Carvajal         64             86           86      84              85
# J. Draxler       86             26           79      68              35
#
#              Strength  Vision Volleys Preferred Positions
# Name
# G. Higuaín     85      70      88                     ST
# Sergio Ramos   81      63      66                     CB
# K. De Bruyne   73      90      82              RM CM CAM
# T. Courtois    70      44      12                     GK
# A. Sánchez     72      83      83            RM LW ST LM
# ...               ...     ...     ...                 ...
# A. Laporte     84      52      40                     CB
# D. Alli        71      83      76              LM CF CAM
# S. Mané        72      78      68                  LW RW
# Carvajal       75      57      34                     RB
# J. Draxler     67      84      84              LM CAM LW
#
# [91 rows x 38 columns]

# %%
# list slicing

# %%
df.loc['M. Neuer']
# Out:
# Age                         31
# Nationality            Germany
# Overall                     92
# Acceleration            58
# Aggression              29
# Agility                 52
# Balance                 35
# Ball control            48
# Composure               70
# Crossing                15
# Curve                   14
# Dribbling               30
# Finishing               13
# Free kick accuracy      11
# GK diving               91
# GK handling             90
# GK kicking              95
# GK positioning          91
# GK reflexes             89
# Heading accuracy        25
# Interceptions           30
# Jumping                 78
# Long passing            59
# Long shots              16
# Marking                 10
# Penalties               47
# Positioning             12
# Reactions               85
# Short passing           55
# Shot power              25
# Sliding tackle          11
# Sprint speed            61
# Stamina                 44
# Standing tackle         10
# Strength                83
# Vision                  70
# Volleys                 11
# Preferred Positions        GK
# Name: M. Neuer, dtype: object

# %% [markdown]
# When using iloc you must specify interger location

# %%
df.loc[['M. Neuer']]
# Out:
#           Age Nationality  Overall Acceleration Aggression Agility Balance  \
# Name
# M. Neuer   31     Germany       92       58         29      52      35
#
#          Ball control Composure Crossing  ... Short passing Shot power  \
# Name                                      ...
# M. Neuer       48        70       15      ...        55         25
#
#          Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# Name
# M. Neuer         11           61      44              10       83      70
#
#          Volleys Preferred Positions
# Name
# M. Neuer  11                     GK
#
# [1 rows x 38 columns]

# %%
df[['Aggression']]
# Out:
#                   Aggression
# Name
# Cristiano Ronaldo     63
# L. Messi              48
# Neymar                56
# L. Suárez             78
# M. Neuer              29
# ...                      ...
# A. Kelsey             16
# B. Richardson         44
# J. Young              26
# J. Lundstram          46
# L. Sackey             52
#
# [17981 rows x 1 columns]

# %%
df[['Age', 'Strength']]
# Out:
#                    Age Strength
# Name
# Cristiano Ronaldo   32   80
# L. Messi            30   59
# Neymar              25   53
# L. Suárez           30   80
# M. Neuer            31   83
# ...                ...      ...
# A. Kelsey           17   50
# B. Richardson       47   47
# J. Young            17   32
# J. Lundstram        18   46
# L. Sackey           18   67
#
# [17981 rows x 2 columns]

# %%
df.iloc[0:5][['Age', 'Nationality']]
# Out:
#                    Age Nationality
# Name
# Cristiano Ronaldo   32    Portugal
# L. Messi            30   Argentina
# Neymar              25      Brazil
# L. Suárez           30     Uruguay
# M. Neuer            31     Germany

# %%
df[['Age', 'Overall', 'Nationality']].iloc[0:5]
# Out:
#                    Age  Overall Nationality
# Name
# Cristiano Ronaldo   32       94    Portugal
# L. Messi            30       93   Argentina
# Neymar              25       92      Brazil
# L. Suárez           30       92     Uruguay
# M. Neuer            31       92     Germany

# %% [markdown]
# Exercise: select, rating, age and nationality for players above 35 and above

# %%
for players in df:
    if players[Age] == 35:
        print(players)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 2
#       1 for players in df:
# ----> 2     if players[Age] == 35:
#       3         print(players)
#
# NameError: name 'Age' is not defined

# %%
age_35
# Out:
# <function __main__.age_35()>

# %%
df.reset_index(inplace=True)

# %%
mask_suarez = df['Name'] == 'L. Suárez'

# %%
df[mask_suarez]
# Out:
#             Name  Age Nationality  Overall Acceleration Aggression Agility  \
# 3      L. Suárez   30     Uruguay       92       88         78      86
# 5052   L. Suárez   21   Argentina       70       75         36      88
# 11570  L. Suárez   22   Argentina       64       68         56      53
#
#       Balance Ball control Composure  ... Short passing Shot power  \
# 3      60           91        83      ...        83         87
# 5052   91           73        61      ...        73         56
# 11570  55           55        48      ...        55         46
#
#       Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 3             38           77      89              45       80      84
# 5052          11           68      46              22       38      75
# 11570         69           67      70              67       76      31
#
#       Volleys Preferred Positions
# 3      88                     ST
# 5052   59                  LM RM
# 11570  30                     LB
#
# [3 rows x 39 columns]

# %%
df[mask['Name'] = df[mask_suarez]['Name'].str.replace('L. Suárez', 'L. Suarez')
# Out:
# C:\Users\KLAUS\AppData\Local\Temp\ipykernel_16496\1805857157.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[mask_suarez]['Name'] = df[mask_suarez]['Name'].str.replace('L. Suárez', 'L. Suarez')
# C:\Users\KLAUS\AppData\Local\Temp\ipykernel_16496\1805857157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[mask_suarez]['Name'] = df[mask_suarez]['Name'].str.replace('L. Suárez', 'L. Suarez')

# %%
df[mask_suarez]
# Out:
#             Name  Age Nationality  Overall Acceleration Aggression Agility  \
# 3      L. Suárez   30     Uruguay       92       88         78      86
# 5052   L. Suárez   21   Argentina       70       75         36      88
# 11570  L. Suárez   22   Argentina       64       68         56      53
#
#       Balance Ball control Composure  ... Short passing Shot power  \
# 3      60           91        83      ...        83         87
# 5052   91           73        61      ...        73         56
# 11570  55           55        48      ...        55         46
#
#       Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 3             38           77      89              45       80      84
# 5052          11           68      46              22       38      75
# 11570         69           67      70              67       76      31
#
#       Volleys Preferred Positions
# 3      88                     ST
# 5052   59                  LM RM
# 11570  30                     LB
#
# [3 rows x 39 columns]

# %%
LIVE SESSIONS mth3 wk3 wed
